# %% [markdown]
# ### Load Package

# %%
import pickle
import ast
import numpy as np
import pandas as pd
import openai
from getpass import getpass
from openai.embeddings_utils import get_embedding
from openai.embeddings_utils import cosine_similarity

# %%
# Open AI API connection 

openai.api_key = "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"

# %% [markdown]
# ### Function

# %%
def find_similar_vectors(search , df):
    # embedding the search term
    search_vector = get_embedding(search , engine="text-embedding-ada-002")
    # prepare the df
    df = df.loc[:,'Verse':]
    df = df.reset_index(drop=True)
    df = df.dropna(subset=['Embeddings'])
    df["similarities"] = df['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
    df = df.sort_values('similarities', ascending=False)
    results = df['Verse'][0:5]
    return results

# %% [markdown]
# ### Quraan

# %%
# Load the DataFrame from the pickle file
with open('Data/x.pickle', 'rb') as f:
    embedded_quraan = pickle.load(f)

# %%
find_similar_vectors('love',embedded_quraan)
# Out:
# 0    And you love wealth with immense love.
# 1                  That laps to the hearts.
# 2         Alas, you love the fleeting life.
# 3                    And lovely companions.
# 4                                   In awe.
# Name: Verse, dtype: object

# %%
find_similar_vectors('freedom',embedded_quraan)
# Out:
# 714                          The freeing of a slave.
# 678                   And others fettered in chains.
# 796     Every soul is hostage to what it has earned.
# 738         With Us are shackles, and a Fierce Fire.
# 1535              For the oppressors, a destination.
# Name: Verse, dtype: object

# %%
find_similar_vectors('sacrifice',embedded_quraan)
# Out:
# 1342                  So pray to your Lord and sacrifice.
# 745           And We redeemed him with a great sacrifice.
# 5                                      Noble and devoted.
# 134     You will not attain virtuous conduct until you...
# 2010    O you who believe! do not kill game while you ...
# Name: Verse, dtype: object

# %%
find_similar_vectors('death',embedded_quraan)
# Out:
# 842                      You will die, and they will die.
# 2693                      Then, after that, you will die.
# 2542                              He will call for death.
# 2227    Then, when We decreed death for him, nothing i...
# 1438          And that it is He who gives death and life.
# Name: Verse, dtype: object

# %%
find_similar_vectors('birth',embedded_quraan)
# Out:
# 1237    It is He who created you from dust, then from ...
# 369     We have enjoined upon man kindness to his pare...
# 858                    Although He created you in stages.
# 552     God created you from dust, then from a small d...
# 24                                 An orphan near of kin.
# Name: Verse, dtype: object

# %%
find_similar_vectors('happiness',embedded_quraan)
# Out:
# 53                   These are the people of happiness.
# 9                 He used to be happy among his family.
# 91                       The virtuous will be in bliss.
# 45    Then happiness, and flowers, and Garden of Del...
# 23                              Laughing and rejoicing.
# Name: Verse, dtype: object

# %%
find_similar_vectors('sadness',embedded_quraan)
# Out:
# 19                            The human being is in loss.
# 69                                Overwhelmed by remorse.
# 1372    Although they were before this—before it was s...
# 63                   Touched by adversity, he is fretful.
# 715     And when one of them is given news of a female...
# Name: Verse, dtype: object

# %% [markdown]
# ### Bible

# %%
df=pd.read_csv('embedded_bible.csv')

# %%
df.to_pickle('data/bible.pickle')

# %%
# Load the DataFrame from the pickle file
with open('Data/bible.pickle', 'rb') as f:
    embedded_bible = pickle.load(f)

# %%
type(embedded_bible['Embeddings'][1])
# Out:
# str

# %%
embedded_bible
# Out:
#                                                  Verses  \
# 0                 The Gospel According to Saint Matthew
# 1     1:1 The book of the generation of Jesus Christ...
# 2     1:2 Abraham begat Isaac; and Isaac begat Jacob...
# 3     1:3 And Judas begat Phares and Zara of Thamar;...
# 4     1:4 And Aram begat Aminadab; and Aminadab bega...
# ...                                                 ...
# 8016  22:18 For I testify unto every man that hearet...
# 8017  22:19 And if any man shall take away from the ...
# 8018  22:20 He which testifieth these things saith, ...
# 8019                         Even so, come, Lord Jesus.
# 8020  22:21 The grace of our Lord Jesus Christ be wi...
#
#                                              Embeddings
# 0     [0.009820213541388512, -0.003338872455060482, ...
# 1     [-0.010279255919158459, -0.020801808685064316,...
# 2     [-0.008396243676543236, -0.027051126584410667,...
# 3     [-0.00023184508609119803, -0.03138377889990806...
# 4     [-0.005143359303474426, -0.018894745036959648,...
# ...                                                 ...
# 8016  [-0.0236080139875412, -0.025152942165732384, -...
# 8017  [-0.012474363669753075, -0.03830690309405327, ...
# 8018  [-0.01618151180446148, -0.02689913660287857, -...
# 8019  [0.0014062980189919472, -0.051537349820137024,...
# 8020  [0.005288987420499325, -0.006964190863072872, ...
#
# [8021 rows x 2 columns]

# %%
embedded_bible = embedded_bible.rename(columns={"Verses": "Verse"})

# %%
find_similar_vectors('sadness',embedded_bible)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 find_similar_vectors('sadness',embedded_bible)
#
# Cell In[4], line 7, in find_similar_vectors(search, df)
#       5 df = df.loc[:,'Verse':]
#       6 df = df.reset_index(drop=True)
# ----> 7 df = df.dropna(subset=['Embeddings'])
#       8 df["similarities"] = df['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
#       9 df = df.sort_values('similarities', ascending=False)
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/frame.py:6558, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6556     check = indices == -1
#    6557     if check.any():
# -> 6558         raise KeyError(np.array(subset)[check].tolist())
#    6559     agg_obj = self.take(indices, axis=agg_axis)
#    6561 if thresh is not no_default:
#
# KeyError: ['Embeddings']

# %%
search='love'
search_vector = get_embedding(search , engine="text-embedding-ada-002")

# %%
type(embedded_quraan['Embeddings'][1])
# Out:
# list

# %%
embedded_quraan['Embeddings'][1]
# Out:
# [-0.0012721412349492311,
#  0.010375075973570347,
#  0.01036825031042099,
#  -0.028886394575238228,
#  -0.013432992622256279,
#  0.018402108922600746,
#  0.005603906232863665,
#  -0.009330742992460728,
#  -0.02017679251730442,
#  -0.0057062916457653046,
#  0.010825572535395622,
#  0.02795809879899025,
#  -0.02215624786913395,
#  -0.029104817658662796,
#  -0.0033070554491132498,
#  0.00447425153106451,
#  0.02874988131225109,
#  -0.007132864557206631,
#  0.023384874686598778,
#  -0.01366506703197956,
#  -0.02522781677544117,
#  -0.002552814781665802,
#  0.006781340576708317,
#  0.008975805714726448,
#  -0.013398864306509495,
#  -0.01706426963210106,
#  0.02088666521012783,
#  -0.010832398198544979,
#  0.003563019447028637,
0.002089304383844137, 0.006836617831140757, 0.006213171873241663, 0.011276770383119583, -0.023222604766488075, -0.02453640289604664, -0.006124977022409439, -0.000779307505581528, 0.0038227885961532593, -0.008241652511060238, -0.010267091915011406, 0.009147929958999157, 0.002414712915197015, 0.007955779321491718, 0.00844845362007618, -0.020765313878655434, 0.022930648177862167, -0.033136915415525436, -0.028003370389342308, -0.004041755106300116, 0.006471673958003521, 0.0068183704279363155, 0.013113655149936676, -0.00951287429779768, -0.005814774427562952, -0.009883900173008442, 0.025059489533305168, 0.021178917959332466, -0.04707777872681618, -0.0010507346596568823, -0.005030144937336445, -0.005595808383077383, -0.008770820684731007, -0.015643933787941933, -0.03880571201443672, 0.016154855489730835, -0.010662447661161423, 0.026251638308167458, -0.02277250587940216, -0.0005553991650231183, 0.025643398985266685, 0.01131326425820589, -0.02077747881412506, 0.039024680852890015, -0.00016679082182236016, 0.0033027431927621365, -0.013210972771048546, -0.003022952936589718, 0.000456940324511379, 0.0188432764261961, 0.01889193430542946, 0.0049176206812262535, -0.035180602222681046, -0.010565129108726978, 0.02206694707274437, -0.04639654979109764, -0.009111435152590275, -0.010303585790097713, 0.008862056769430637, 0.03230971097946167, 0.007931449450552464, 0.006544662639498711, -0.0019859035965055227, -0.04009518027305603, 0.017578136175870895, -0.011556560173630714, 0.022833330556750298, -0.017541641369462013, -0.03466968238353729, 0.03359917923808098, 0.013089325278997421, -0.01850266195833683, 0.0002012894256040454, 0.01883111149072647, 0.008582266978919506, 0.00033985410118475556, 0.02561906911432743, -0.0011548957554623485, -0.007019090000540018, 0.02780873328447342, 0.026081331074237823, 0.018952758982777596, -0.00032122674747370183, 0.03591049090027809, 0.0017547725001350045, -0.014074673876166344, 0.03836778178811073, -0.010692859068512917, -0.009020199067890644, -0.005547149106860161, 0.030484989285469055, -0.016057536005973816, -0.023210439831018448, 0.008722161874175072, 0.0371999591588974, -0.008351135067641735, -0.01328396238386631, -0.007663824129849672, -0.014780232682824135, 0.004713860340416431, -0.001516798511147499, -0.028052030131220818, 0.03325856477022171, -0.008174746297299862, 0.0007348299841396511, -0.0008606596384197474, -0.0079922741279006,  ...

# %%
# prepare the df
embedded_bible = embedded_bible.loc[:,'Verse':]
embedded_bible = embedded_bible.reset_index(drop=True)
embedded_bible = embedded_bible.dropna(subset=['Embeddings'])
embedded_bible["similarities"] = embedded_bible['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
# df = df.sort_values('similarities', ascending=False)
# results = df['Verse'][0:5]
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[139], line 5
#       3 embedded_bible = embedded_bible.reset_index(drop=True)
#       4 embedded_bible = embedded_bible.dropna(subset=['Embeddings'])
# ----> 5 embedded_bible["similarities"] = embedded_bible['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
#       6 # df = df.sort_values('similarities', ascending=False)
#       7 # results = df['Verse'][0:5]
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/series.py:4631, in apply(self, func, convert_dtype, args, **kwargs)
#    4611 @overload  # type: ignore[override]
#    4612 def any(
#    4613     self,
#    (...)
#    4619     **kwargs,
#    4620 ) -> bool:
#    4621     ...
#    4623 @overload
#    4624 def any(
#    4625     self,
#    4626     *,
#    4627     axis: Axis = ...,
#    4628     bool_only: bool | None = ...,
#    4629     skipna: bool = ...,
#    4630     level: Level,
# -> 4631     **kwargs,
#    4632 ) -> Series | bool:
#    4633     ...
#    4635 @doc(NDFrame.any, **_shared_doc_kwargs)
#    4636 def any(
#    4637     self,
#    (...)
#    4642     **kwargs,
#    4643 ) -> Series | bool:
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/apply.py:1025, in apply(self)
#    1021             object.__setattr__(ser, "_name", name)
#    1022             yield ser
#    1024 @property
# -> 1025 def result_index(self) -> Index:
#    1026     return self.index
#    1028 @property
#    1029 def result_columns(self) -> Index:
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/apply.py:1076, in apply_standard(self)
#    1068 obj: Series
#    1069 axis = 0
#    1071 def __init__(
#    1072     self,
#    1073     obj: Series,
#    1074     func: AggFuncType,
#    1075     convert_dtype: bool,
# -> 1076     args,
#    1077     kwargs,
#    1078 ) -> None:
#    1079     self.convert_dtype = convert_dtype
#    1081     super().__init__(
#    1082         obj,
#    1083         func,
#    (...)
#    1087         kwargs=kwargs,
#    1088     )
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[139], line 5, in <lambda>(x)
#       3 embedded_bible = embedded_bible.reset_index(drop=True)
#       4 embedded_bible = embedded_bible.dropna(subset=['Embeddings'])
# ----> 5 embedded_bible["similarities"] = embedded_bible['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
#       6 # df = df.sort_values('similarities', ascending=False)
#       7 # results = df['Verse'][0:5]
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/openai/embeddings_utils.py:68, in cosine_similarity(a, b)
#      67 def cosine_similarity(a, b):
# ---> 68     return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U34466'), dtype('<U23')) -> None

# %%
embedded_bible
# Out:
#                                                   Verse
# 0                 The Gospel According to Saint Matthew  \
# 1     1:1 The book of the generation of Jesus Christ...
# 2     1:2 Abraham begat Isaac; and Isaac begat Jacob...
# 3     1:3 And Judas begat Phares and Zara of Thamar;...
# 4     1:4 And Aram begat Aminadab; and Aminadab bega...
# ...                                                 ...
# 8016  22:18 For I testify unto every man that hearet...
# 8017  22:19 And if any man shall take away from the ...
# 8018  22:20 He which testifieth these things saith, ...
# 8019                         Even so, come, Lord Jesus.
# 8020  22:21 The grace of our Lord Jesus Christ be wi...
#
#                                              Embeddings
# 0     [0.009820213541388512, -0.003338872455060482, ...
# 1     [-0.010279255919158459, -0.020801808685064316,...
# 2     [-0.008396243676543236, -0.027051126584410667,...
# 3     [-0.00023184508609119803, -0.03138377889990806...
# 4     [-0.005143359303474426, -0.018894745036959648,...
# ...                                                 ...
# 8016  [-0.0236080139875412, -0.025152942165732384, -...
# 8017  [-0.012474363669753075, -0.03830690309405327, ...
# 8018  [-0.01618151180446148, -0.02689913660287857, -...
# 8019  [0.0014062980189919472, -0.051537349820137024,...
# 8020  [0.005288987420499325, -0.006964190863072872, ...
#
# [8021 rows x 2 columns]

# %%
find_similar_vectors('sadness',embedded_bible)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 find_similar_vectors('sadness',embedded_bible)
#
# Cell In[98], line 8, in find_similar_vectors(search, df)
#       6 df = df.reset_index(drop=True)
#       7 df = df.dropna(subset=['Embeddings'])
# ----> 8 df["similarities"] = df['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
#       9 df = df.sort_values('similarities', ascending=False)
#      10 results = df['Verse'][0:5]
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/series.py:4631, in apply(self, func, convert_dtype, args, **kwargs)
#    4611 @overload  # type: ignore[override]
#    4612 def any(
#    4613     self,
#    (...)
#    4619     **kwargs,
#    4620 ) -> bool:
#    4621     ...
#    4623 @overload
#    4624 def any(
#    4625     self,
#    4626     *,
#    4627     axis: Axis = ...,
#    4628     bool_only: bool | None = ...,
#    4629     skipna: bool = ...,
#    4630     level: Level,
# -> 4631     **kwargs,
#    4632 ) -> Series | bool:
#    4633     ...
#    4635 @doc(NDFrame.any, **_shared_doc_kwargs)
#    4636 def any(
#    4637     self,
#    (...)
#    4642     **kwargs,
#    4643 ) -> Series | bool:
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/apply.py:1025, in apply(self)
#    1021             object.__setattr__(ser, "_name", name)
#    1022             yield ser
#    1024 @property
# -> 1025 def result_index(self) -> Index:
#    1026     return self.index
#    1028 @property
#    1029 def result_columns(self) -> Index:
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/core/apply.py:1076, in apply_standard(self)
#    1068 obj: Series
#    1069 axis = 0
#    1071 def __init__(
#    1072     self,
#    1073     obj: Series,
#    1074     func: AggFuncType,
#    1075     convert_dtype: bool,
# -> 1076     args,
#    1077     kwargs,
#    1078 ) -> None:
#    1079     self.convert_dtype = convert_dtype
#    1081     super().__init__(
#    1082         obj,
#    1083         func,
#    (...)
#    1087         kwargs=kwargs,
#    1088     )
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[98], line 8, in find_similar_vectors.<locals>.<lambda>(x)
#       6 df = df.reset_index(drop=True)
#       7 df = df.dropna(subset=['Embeddings'])
# ----> 8 df["similarities"] = df['Embeddings'].apply(lambda x: cosine_similarity(x, search_vector))
#       9 df = df.sort_values('similarities', ascending=False)
#      10 results = df['Verse'][0:5]
#
# File ~/opt/anaconda3/envs/ivy/lib/python3.9/site-packages/openai/embeddings_utils.py:68, in cosine_similarity(a, b)
#      67 def cosine_similarity(a, b):
# ---> 68     return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U34466'), dtype('<U23')) -> None
